# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes = True)
# %matplotlib inline

# %%
print(np.__version__)
print(pd.__version__)
print(sns.__version__)
import sys
print(sys.version)
# Out:
# 1.21.5
# 1.4.2
# 0.11.2
# 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]

# %%
df = pd.read_csv('C:/Users/sm214/Downloads/iris.data')

# %%
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
col_name = ['sepal length', 'sepal width', 'petal length', 'petal width', 'class']

# %%
df.columns = col_name

# %%
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.848322     3.051007      3.774497     1.205369
# std        0.828594     0.433499      1.759651     0.761292
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(iris.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
print(iris.groupby('species').size())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
sns.pairplot(iris, hue='species', height=3, aspect=1)

# %%
iris.hist(edgecolor='black',linewidth=1.2, figsize=(12,8))
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
sns.violinplot(x='species', y='sepal_length', data=iris)
plt.subplot(2,2,2)
sns.violinplot(x='species', y='sepal_width', data=iris)
plt.subplot(2,2,3)
sns.violinplot(x='species', y='petal_width', data=iris)
plt.subplot(2,2,4)
sns.violinplot(x='species', y='petal_length', data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
iris.boxplot(by='species', figsize=(12,8))
# Out:
# array([[<AxesSubplot:title={'center':'petal_length'}, xlabel='[species]'>,
#         <AxesSubplot:title={'center':'petal_width'}, xlabel='[species]'>],
#        [<AxesSubplot:title={'center':'sepal_length'}, xlabel='[species]'>,
#         <AxesSubplot:title={'center':'sepal_width'}, xlabel='[species]'>]],
#       dtype=object)

# %%
pd.plotting.scatter_matrix(iris, figsize=(12,10))
plt.show()

# %%
sns.pairplot(iris, hue='species', diag_kind='kde')

# %%
generate_random = np.random.RandomState(0)
x = 10*generate_random.rand(100)

# %%
y = 3*x + np.random.randn(100)

# %%
plt.figure(figsize=(10,8))
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(fit_intercept=True)

# %%
model
# Out:
# LinearRegression()

# %%
X = x.reshape(-1,1)

# %%
X.shape
# Out:
# (100, 1)

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([2.96926725])

# %%
model.intercept_
# Out:
# 0.22644751245340977

# %%
x_fit = np.linspace(-1,11)

# %%
X_fit = x_fit.reshape(-1,1)

# %%
y_fit = model.predict(X_fit)

# %%
plt.figure(figsize = (10,8))
plt.scatter(x,y)
plt.plot(x_fit,y_fit)

# %%
import numpy as np
import pandas as pd
import sklearn

# %%
print(np.__version__)
print(pd.__version__)
import sys
print(sys.version)
print(sklearn.__version__)
# Out:
# 1.21.5
# 1.4.2
# 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]
# 1.0.2

# %%
df = pd.read_csv('C:/Users/sm214/Downloads/archive/HousingData.csv')

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
col_names = df.columns

# %%
print(col_names)
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.999513    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.175000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     76.800000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.975000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  486.000000  506.000000
# mean    12.715432   22.532806
# std      7.155871    9.197104
# min      1.730000    5.000000
# 25%      7.125000   17.025000
# 50%     11.430000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
sns.pairplot(df,height=2.5)
plt.show()

# %%
pd.options.display.float_format = '{:,.3f}'.format

# %%
df.corr()
# Out:
#           CRIM     ZN  INDUS   CHAS    NOX     RM    AGE    DIS    RAD    TAX  \
# CRIM     1.000 -0.191  0.402 -0.054  0.417 -0.219  0.354 -0.374  0.625  0.581
# ZN      -0.191  1.000 -0.532 -0.037 -0.514  0.321 -0.564  0.657 -0.311 -0.312
# INDUS    0.402 -0.532  1.000  0.060  0.765 -0.390  0.638 -0.712  0.605  0.731
# CHAS    -0.054 -0.037  0.060  1.000  0.075  0.105  0.079 -0.094  0.001 -0.032
# NOX      0.417 -0.514  0.765  0.075  1.000 -0.302  0.732 -0.769  0.611  0.668
# RM      -0.219  0.321 -0.390  0.105 -0.302  1.000 -0.247  0.205 -0.210 -0.292
# AGE      0.354 -0.564  0.638  0.079  0.732 -0.247  1.000 -0.745  0.458  0.509
# DIS     -0.374  0.657 -0.712 -0.094 -0.769  0.205 -0.745  1.000 -0.495 -0.534
# RAD      0.625 -0.311  0.605  0.001  0.611 -0.210  0.458 -0.495  1.000  0.910
# TAX      0.581 -0.312  0.731 -0.032  0.668 -0.292  0.509 -0.534  0.910  1.000
# PTRATIO  0.281 -0.414  0.391 -0.111  0.189 -0.356  0.269 -0.232  0.465  0.461
# B       -0.381  0.171 -0.361  0.051 -0.380  0.128 -0.275  0.292 -0.444 -0.442
# LSTAT    0.445 -0.414  0.591 -0.047  0.583 -0.614  0.603 -0.493  0.480  0.536
# MEDV    -0.391  0.373 -0.482  0.181 -0.427  0.695 -0.395  0.250 -0.382 -0.469
#
#          PTRATIO      B  LSTAT   MEDV
# CRIM       0.281 -0.381  0.445 -0.391
# ZN        -0.414  0.171 -0.414  0.373
# INDUS      0.391 -0.361  0.591 -0.482
# CHAS      -0.111  0.051 -0.047  0.181
# NOX        0.189 -0.380  0.583 -0.427
# RM        -0.356  0.128 -0.614  0.695
# AGE        0.269 -0.275  0.603 -0.395
# DIS       -0.232  0.292 -0.493  0.250
# RAD        0.465 -0.444  0.480 -0.382
# TAX        0.461 -0.442  0.536 -0.469
# PTRATIO    1.000 -0.177  0.376 -0.508
# B         -0.177  1.000 -0.370  0.333
# LSTAT      0.376 -0.370  1.000 -0.736
# MEDV      -0.508  0.333 -0.736  1.000

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df[['CRIM', 'ZN', 'INDUS', 'CHAS']].corr(), annot = True)
plt.show()

# %%
df.corr()
# Out:
#           CRIM     ZN  INDUS   CHAS    NOX     RM    AGE    DIS    RAD    TAX  \
# CRIM     1.000 -0.191  0.402 -0.054  0.417 -0.219  0.354 -0.374  0.625  0.581
# ZN      -0.191  1.000 -0.532 -0.037 -0.514  0.321 -0.564  0.657 -0.311 -0.312
# INDUS    0.402 -0.532  1.000  0.060  0.765 -0.390  0.638 -0.712  0.605  0.731
# CHAS    -0.054 -0.037  0.060  1.000  0.075  0.105  0.079 -0.094  0.001 -0.032
# NOX      0.417 -0.514  0.765  0.075  1.000 -0.302  0.732 -0.769  0.611  0.668
# RM      -0.219  0.321 -0.390  0.105 -0.302  1.000 -0.247  0.205 -0.210 -0.292
# AGE      0.354 -0.564  0.638  0.079  0.732 -0.247  1.000 -0.745  0.458  0.509
# DIS     -0.374  0.657 -0.712 -0.094 -0.769  0.205 -0.745  1.000 -0.495 -0.534
# RAD      0.625 -0.311  0.605  0.001  0.611 -0.210  0.458 -0.495  1.000  0.910
# TAX      0.581 -0.312  0.731 -0.032  0.668 -0.292  0.509 -0.534  0.910  1.000
# PTRATIO  0.281 -0.414  0.391 -0.111  0.189 -0.356  0.269 -0.232  0.465  0.461
# B       -0.381  0.171 -0.361  0.051 -0.380  0.128 -0.275  0.292 -0.444 -0.442
# LSTAT    0.445 -0.414  0.591 -0.047  0.583 -0.614  0.603 -0.493  0.480  0.536
# MEDV    -0.391  0.373 -0.482  0.181 -0.427  0.695 -0.395  0.250 -0.382 -0.469
#
#          PTRATIO      B  LSTAT   MEDV
# CRIM       0.281 -0.381  0.445 -0.391
# ZN        -0.414  0.171 -0.414  0.373
# INDUS      0.391 -0.361  0.591 -0.482
# CHAS      -0.111  0.051 -0.047  0.181
# NOX        0.189 -0.380  0.583 -0.427
# RM        -0.356  0.128 -0.614  0.695
# AGE        0.269 -0.275  0.603 -0.395
# DIS       -0.232  0.292 -0.493  0.250
# RAD        0.465 -0.444  0.480 -0.382
# TAX        0.461 -0.442  0.536 -0.469
# PTRATIO    1.000 -0.177  0.376 -0.508
# B         -0.177  1.000 -0.370  0.333
# LSTAT      0.376 -0.370  1.000 -0.736
# MEDV      -0.508  0.333 -0.736  1.000

# %%
import matplotlib as mpl
mpl.__version__
# Out:
# '3.5.1'

# %%
X = df['RM'].values.reshape(-1,1)

# %%
y = df['MEDV'].values

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([9.10210898])

# %%
model.intercept_
# Out:
# -34.670620776438554

# %%
plt.figure(figsize=(12,10))
sns.regplot(X,y)
plt.xlabel('average number')
plt.ylabel('Median value')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
model.predict(np.array([5]).reshape(1,-1))
# Out:
# array([10.83992413])

# %% [markdown]
# Robust Regression

# %%
X = df['RM'].values.reshape(-1,1)
y = df['MEDV'].values

# %%
from sklearn.linear_model import RANSACRegressor

# %%
ransac = RANSACRegressor()

# %%
ransac.fit(X,y)
# Out:
# RANSACRegressor()

# %%
inlier_mask = ransac.inlier_mask_
outlier_mask = np.logical_not(inlier_mask)

# %%
np.arange(3,10,1)
# Out:
# array([3, 4, 5, 6, 7, 8, 9])

# %%
line_X = np.arange(3,10,1)
line_y_ransac = ransac.predict(line_X.reshape(-1,1))

# %%
sns.set(style ='darkgrid', context='notebook')
plt.figure(figsize=(12,8))
plt.scatter(X[inlier_mask], y[inlier_mask], c='blue', marker='o', label='Inliers')
plt.scatter(X[outlier_mask],y[outlier_mask],c='brown', marker='s', label='Outliers')

# %%
plt.plot(line_X,line_y_ransac,color='red')
plt.xlabel('average number of rooms per dwelling')
plt.ylabel('Median value of owner-occupied homes in $1000')
plt.legend(loc='upper left')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.iloc[:,:-1].values

# %%
y = df['TAX'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

# %%
lr = LinearRegression()
